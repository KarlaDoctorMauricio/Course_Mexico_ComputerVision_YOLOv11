# %% [markdown]
# # Instalacion de librerias

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 30.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 50.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 44.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# # Predicciones

# %% [markdown]
# ## Detección de objetos

# %%
model_name = "yolo11n.pt"
source   = 'https://ultralytics.com/images/bus.jpg'
# !yolo predict model=$model_name source=$source
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 5.35M/5.35M [00:00<00:00, 314MB/s]
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# ...
# 100% 134k/134k [00:00<00:00, 45.8MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 77.1ms
# Speed: 16.0ms preprocess, 77.1ms inference, 436.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## Segmentación de imágenes

# %%
model_name = "yolo11n-seg.pt"
source   = 'https://ultralytics.com/images/bus.jpg'
# !yolo predict model=$model_name source=$source
# Out:
# ...
# 100% 5.90M/5.90M [00:00<00:00, 390MB/s]
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-seg summary (fused): 113 layers, 2,868,664 parameters, 0 gradients, 10.4 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 64.5ms
# Speed: 3.7ms preprocess, 64.5ms inference, 202.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## Clasificación de imágenes

# %%
model_name = "yolo11n-cls.pt"
source   = 'https://ultralytics.com/images/bus.jpg'
# !yolo predict model=$model_name source=$source
# Out:
# ...
# 100% 5.52M/5.52M [00:00<00:00, 346MB/s]
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-cls summary (fused): 47 layers, 2,807,024 parameters, 0 gradients, 4.2 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# ...
# 100% 755k/755k [00:00<00:00, 110MB/s]
# image 1/1 /content/bus.jpg: 224x224 minibus 0.57, police_van 0.34, trolleybus 0.04, recreational_vehicle 0.01, streetcar 0.01, 5.1ms
# Speed: 37.0ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## Estimación de poses

# %%
model_name = "yolo11n-pose.pt"
source   = 'https://ultralytics.com/images/bus.jpg'
# !yolo predict model=$model_name source=$source
# Out:
# ...
# 100% 5.97M/5.97M [00:00<00:00, 153MB/s]
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-pose summary (fused): 109 layers, 2,866,468 parameters, 0 gradients, 7.4 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 62.9ms
# Speed: 5.4ms preprocess, 62.9ms inference, 160.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/pose/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # Entrenamiento

# %%
yaml ="custom_data.yaml"
# !yolo detect train epochs=100 batch=16 plots=True model=yolov10n.pt data=$yaml device=0
# Out:
# ...
# 100% 5.59M/5.59M [00:00<00:00, 308MB/s]
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # Validación

# %%
model = "runs/detect/train/weights/best.pt"
source ="custom_dataset/dataset/valid/images"
# !yolo detect predict conf=0.25 save=True model=$model source=$source
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10n summary (fused): 125 layers, 2,694,806 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/60 /content/YOLOv10-Custom-Object-Detection/custom_dataset/dataset/valid/images/Cars110_png.rf.6ae216cbfe78f745cf14eeea3a39dde5.jpg: 448x640 1 licence, 49.0ms
# image 2/60 /content/YOLOv10-Custom-Object-Detection/custom_dataset/dataset/valid/images/Cars116_png.rf.0148b13b5883fc5aad7404fb2ef8095a.jpg: 544x640 1 licence, 45.9ms
# image 3/60 /content/YOLOv10-Custom-Object-Detection/custom_dataset/dataset/valid/images/Cars118_png.rf.e24fe66e9b75dbb070c73c4d7025cff3.jpg: 416x640 2 licences, 48.3ms
# image 4/60 /content/YOLOv10-Custom-Object-Detection/custom_dataset/dataset/valid/images/Cars11_png.rf.bf5befb517adbbec3724f47b8088d039.jpg: 512x640 1 licence, 45.7ms
# ...

# %% [markdown]
# # Test

# %%
model = "runs/detect/train/weights/best.pt"
img = "custom_dataset/dataset/test/images"
# !yolo detect predict conf=0.25 save=True model=$model source=$source
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10n summary (fused): 125 layers, 2,694,806 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/60 /content/YOLOv10-Custom-Object-Detection/custom_dataset/dataset/valid/images/Cars110_png.rf.6ae216cbfe78f745cf14eeea3a39dde5.jpg: 448x640 1 licence, 74.6ms
# image 2/60 /content/YOLOv10-Custom-Object-Detection/custom_dataset/dataset/valid/images/Cars116_png.rf.0148b13b5883fc5aad7404fb2ef8095a.jpg: 544x640 1 licence, 68.3ms
# image 3/60 /content/YOLOv10-Custom-Object-Detection/custom_dataset/dataset/valid/images/Cars118_png.rf.e24fe66e9b75dbb070c73c4d7025cff3.jpg: 416x640 2 licences, 66.8ms
# image 4/60 /content/YOLOv10-Custom-Object-Detection/custom_dataset/dataset/valid/images/Cars11_png.rf.bf5befb517adbbec3724f47b8088d039.jpg: 512x640 1 licence, 71.3ms
# ...
